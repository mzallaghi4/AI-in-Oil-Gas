# %% [markdown]
# ### Deep Neural Network-Based Drilling Optimization
#
#     Well Drilling Data (drilling_data.csv)
#                 ↓
#      Data Quality & Visualization
#                 ↓
#      Deep Neural Network (DNN)
#                 ↓
#       ROP Prediction Model
#                 ↓
#     Optimization of Drilling Parameters

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# # Load Dataset ----------------------------------------------

df=pd.read_csv("drilling_data.csv")

print(df.head())
# Out:
#        Depth_m        Formation       UCS_psi  Porosity_percent  \
# 0  1500.000000  Asmar_Carbonate   7920.703699          8.450504
# 1  1500.500083  Asmar_Carbonate   5517.815080         15.966502
# 2  1501.000167  Asmar_Carbonate   9778.926669         17.225444
# 3  1501.500250  Asmar_Carbonate   8966.912800         13.772693
# 4  1502.000333  Asmar_Carbonate  12624.269319         13.897806
#
#    Permeability_mD    WOB_ton         RPM  Torque_kNm  MudWeight_ppg  \
# 0        12.687338  34.804626   84.397940  419.558056       9.750528
# 1        15.291116  27.424995  150.792541  662.582743       9.619736
# 2        26.761495  19.922595  176.053707  521.555775       9.666888
# 3         8.037937  11.124420   90.405892  138.420894       9.433471
# 4         5.833759  19.813808  151.373425  426.709565       9.432264
#
#    FlowRate_gpm  DeltaP_psi   BitWear   ROP_m_hr
# 0    504.268056  553.424895  0.295658  35.744420
# 1    363.296537  331.207125  0.709909  31.194044
# 2    404.782932  419.596246  0.869672  14.661204
# 3    674.358119  729.625735  0.842276   9.996583
# 4    529.242774  980.828433  0.553395  18.461681
