# %% [markdown]
# ## AI-Based CDU Digital Optimization System
#
# Objective: Develop an AI model that predicts refinery CDU performance and determines optimal operating conditions.
#
# The AI system will optimize:
# - Crude throughput
# - Furnace outlet temperature
# - Column pressure
# - Steam injection
# - Reflux ratio
# - Product yields
# - Energy consumption

# %% [markdown]
# #### Deep Neural Network CDU Model

# %%
# =============  Deep Neural Network Model for CDU Optimization =====================================================
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import plotly.express as px
